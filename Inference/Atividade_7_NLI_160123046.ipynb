# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import tensorflow_datasets as tfds
import requests
import re
from keras.utils.np_utils import to_categorical
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Model
from keras.models import Sequential
from keras.layers import Input, Dense, SimpleRNN, Activation, Embedding, Bidirectional, LSTM
import matplotlib.pyplot as plt

# %% [markdown]
# # Classes and Functions

# %%
#@ Classes

def knn():




class Train:
    def __init__(self, ds_train):
        self.df = None
        self.raw_df = None
        self.sentences = None
        self.labels = None
        self.sequences = None
        self.padded = None


        # take 10000 rows of premise and hypothesis sentences
        self.raw_df = tfds.as_dataframe(ds_train.take(10000))
        # concatenate premise and hypothesis into one sentence
        self.raw_df['premise_hyp'] = self.raw_df.apply(lambda x: conc(str(x['premise']), str(x['hypothesis'])), axis=1)
        # select only desired columns
        self.raw_df = self.raw_df[['premise_hyp', 'label']]
        self.df = self.raw_df.copy()
        # normalize sentences
        self.df['premise_hyp'] = self.df['premise_hyp'].apply(lambda x: normalizarString(x))
        self.df = self.df[self.df['label'] != -1]
        self.sentences = []
        self.labels = []
        for i, row in self.df.iterrows():
            self.sentences.append(row[0])
            self.labels.append(row[1])


class Validation:
    def __init__(self, ds_validation):
        self.df = None
        self.raw_df = None
        self.sentences = None
        self.labels = None
        self.sequences = None
        self.padded = None

        # take 10000 rows of premise and hypothesis sentences
        self.raw_df = tfds.as_dataframe(ds_validation.take(2500))

        # concatenate premise and hypothesis into one sentence
        self.raw_df['premise_hyp'] = self.raw_df.apply(lambda x: conc(str(x['premise']), str(x['hypothesis'])), axis=1)
        # select only desired columns
        self.raw_df = self.raw_df[['premise_hyp', 'label']]
        self.df = self.raw_df.copy()
        # normalize sentences
        self.df['premise_hyp'] = self.df['premise_hyp'].apply(lambda x: normalizarString(x))
        self.df = self.df[self.df['label'] != -1]

        self.sentences = []
        self.labels = []
        for i, row in self.df.iterrows():
            self.sentences.append(row[0])
            self.labels.append(row[1])


class Test:
    def __init__(self, ds_test):
        self.df = None
        self.raw_df = None
        self.sentences = None
        self.labels = None
        self.sequences = None
        self.padded = None

        # take 10000 rows of premise and hypothesis sentences
        self.raw_df = tfds.as_dataframe(ds_test.take(2500))

        # concatenate premise and hypothesis into one sentence
        self.raw_df['premise_hyp'] = self.raw_df.apply(lambda x: conc(str(x['premise']), str(x['hypothesis'])), axis=1)
        # select only desired columns
        self.raw_df = self.raw_df[['premise_hyp', 'label']]
        self.df = self.raw_df.copy()
        # normalize sentences
        self.df['premise_hyp'] = self.df['premise_hyp'].apply(lambda x: normalizarString(x))
        self.df = self.df[self.df['label'] != -1]

        self.sentences = []
        self.labels = []
        for i, row in self.df.iterrows():
            self.sentences.append(row[0])
            self.labels.append(row[1])


class HyperParameters:
    def __init__(self, vocab_size, embedding_dim, max_length, trunc_type, padding_type, epochs):
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.max_length = max_length
        self.trunc_type = trunc_type
        self.padding_type = padding_type
        self.epochs = epochs


class Models:

    def __init__(self, model_name, train, validation,test, hp):
        self.model_name = model_name
        self.hp = hp
        self.model = self.choose_model()
        self.train = train
        self.validation = validation
        self.test = test
        self.history = None
        self.metrics = {
            'accuracy': 'accuracy',
            'loss': 'loss',
        }


    def choose_model(self):
        if self.model_name == 'rnn':
            model = Sequential([
                Embedding(self.hp.vocab_size, self.hp.embedding_dim, input_length=self.hp.max_length),
                SimpleRNN(32),
                Dense(10, activation='relu'),
                Dense(1, activation='sigmoid')
            ])

            ...
            model.summary()
            model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
            return model
        elif self.model_name == 'lstm':
            model = Sequential([
                Embedding(self.hp.vocab_size, self.hp.embedding_dim, input_length=self.hp.max_length),
                LSTM(32),
                Dense(10, activation='relu'),
                Dense(1, activation='sigmoid')
            ])

            ...
            model.summary()
            model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
            return model

        elif self.model_name == 'bilstm':
            model = Sequential([
                Embedding(self.hp.vocab_size, self.hp.embedding_dim, input_length=self.hp.max_length),
                Bidirectional(LSTM(32)),
                Dense(10, activation='relu'),
                Dense(1, activation='sigmoid')
            ])

            ...
            model.summary()
            model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
            return model


    def fit(self):
        self.history = self.model.fit(self.train.padded, self.train.labels, epochs=self.hp.epochs,
                                      validation_data=(self.validation.padded, self.validation.labels), verbose=2)

    def show_plot(self, metric):
        plt.plot(self.history.history[metric])
        plt.plot(self.history.history['val_' + metric], '')
        plt.xlabel("Epochs")
        plt.ylabel(metric)
        plt.legend([metric, 'val_' + metric])
        plt.title(self.model_name + ' ' + metric)
        plt.show()

# %%
#@ Auxiliary functions

def createWordIndexCustom(vocabulary):
    word_index = {}
    for word, index in vocabulary.items():
        word_index[word] = index
    return word_index


def createWordIndex(hp, train, validation, test):
    # creates word_index for vocabulary
    tokenizer = Tokenizer(num_words=hp.vocab_size)
    # fit_on_texts receives a list of sentences. Can be a series of dataframe too
    tokenizer.fit_on_texts(train.sentences)

    train.sequences = tokenizer.texts_to_sequences(train.sentences)
    validation.sequences = tokenizer.texts_to_sequences(validation.sentences)
    test.sequences = tokenizer.texts_to_sequences(test.sentences)

    #
    # max_len = len(train.sequences[0])
    # for train,valid,test in zip(train.sequences,validation.sequences,test.sequences):
    #     if max(len(train),len(valid),len(test)) > max_len:
    #         max_len = max(len(train),len(valid),len(test))



    train.padded = pad_sequences(train.sequences, maxlen=hp.max_length, padding=hp.padding_type,
                                 truncating=hp.trunc_type)
    validation.padded = pad_sequences(validation.sequences, maxlen=hp.max_length, padding=hp.padding_type,
                                      truncating=hp.trunc_type)
    test.padded = pad_sequences(test.sequences, maxlen=hp.max_length, padding=hp.padding_type, truncating=hp.trunc_type)

    train.labels = np.array(train.labels)
    validation.labels = np.array(validation.labels)
    test.labels = np.array(test.labels)




def createVocabulary(train):
    vocabulary = {}
    for i in range(0, len(train.sentences)):
        for word in train.sentences[i].split():
            if word in vocabulary:
                vocabulary[word] += 1
            else:
                vocabulary[word] = 1
    return vocabulary


def conc(x, y):
    return x + y


def normalizarString(text):
    import unicodedata

    text = text.lower()
    text = re.sub(r'(b\')|(\')', '', text)
    return text


def usingStopwords():
    master = "https://raw.githubusercontent.com/guico3lho/NLP_UnB_2022_1/main/stopwords_pt.txt"
    req = requests.get(master)
    text = req.text

    stop_words = []
    pattern = r'\n?'
    rt = re.compile(pattern)

    for i in text.split('\n'):
        stop_words.append(normalizarString(rt.sub('', i)))
    print(f'Fim do Preenchimento das stopwords')

    return stop_words

# %% [markdown]
# # Execution

# %%
stopwords = usingStopwords()
ds_train = tfds.load('snli', split='train', shuffle_files=True)
ds_validation = tfds.load('snli', split='validation', shuffle_files=False)
ds_test = tfds.load('snli', split='test', shuffle_files=False)
# Out:
# Fim do Preenchimento das stopwords

# %%
# preparing data
train = Train(ds_train)
validation = Validation(ds_validation)
test = Test(ds_test)
print("raw df_train:")
display(train.raw_df)
print("df_train after removel of label (-2) and preprocessing")
display(train.df)

train =

# %%
vocabulary = createVocabulary(train)
    
hp = HyperParameters(vocab_size=len(vocabulary), embedding_dim=16, max_length=72, trunc_type='post',
                         padding_type='post', epochs=30)

createWordIndex(hp, train, validation, test)

# %%
rnn_model = Models('rnn', train, validation, test, hp)
rnn_model.fit()
rnn_model.show_plot('loss')
rnn_model.show_plot('accuracy')

lstm_model = Models('lstm', train, validation, test, hp)
lstm_model.fit()
lstm_model.show_plot('loss')
lstm_model.show_plot('accuracy')


bilstm_model = Models('bilstm', train, validation, test, hp)
bilstm_model.fit()
bilstm_model.show_plot('loss')
bilstm_model.show_plot('accuracy')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 72, 16)            249952
#
#  simple_rnn (SimpleRNN)      (None, 32)                1568
#
#  dense (Dense)               (None, 10)                330
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 251,861
# Trainable params: 251,861
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 312/312 - 6s - loss: 0.1441 - accuracy: 0.3262 - val_loss: -1.0309e-01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 2/30
# 312/312 - 4s - loss: 0.0366 - accuracy: 0.3266 - val_loss: -1.3081e-01 - val_accuracy: 0.3219 - 4s/epoch - 14ms/step
# Epoch 3/30
# 312/312 - 4s - loss: 0.0362 - accuracy: 0.3266 - val_loss: -1.4779e-01 - val_accuracy: 0.3219 - 4s/epoch - 12ms/step
# Epoch 4/30
# 312/312 - 4s - loss: 0.0382 - accuracy: 0.3266 - val_loss: -1.5202e-01 - val_accuracy: 0.3219 - 4s/epoch - 12ms/step
# Epoch 5/30
# 312/312 - 4s - loss: 0.0359 - accuracy: 0.3266 - val_loss: -1.6112e-01 - val_accuracy: 0.3219 - 4s/epoch - 12ms/step
# Epoch 6/30
# 312/312 - 4s - loss: 0.0367 - accuracy: 0.3266 - val_loss: -1.5962e-01 - val_accuracy: 0.3219 - 4s/epoch - 11ms/step
# Epoch 7/30
# 312/312 - 5s - loss: 0.0368 - accuracy: 0.3266 - val_loss: -1.4278e-01 - val_accuracy: 0.3219 - 5s/epoch - 15ms/step
# Epoch 8/30
# 312/312 - 5s - loss: 0.0351 - accuracy: 0.3266 - val_loss: -1.4687e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 9/30
# 312/312 - 5s - loss: 0.0352 - accuracy: 0.3266 - val_loss: -1.5258e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 10/30
# 312/312 - 5s - loss: 0.0347 - accuracy: 0.3266 - val_loss: -1.4572e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 11/30
# 312/312 - 4s - loss: 0.0357 - accuracy: 0.3266 - val_loss: -1.5245e-01 - val_accuracy: 0.3219 - 4s/epoch - 13ms/step
# Epoch 12/30
# 312/312 - 4s - loss: 0.0367 - accuracy: 0.3266 - val_loss: -1.4990e-01 - val_accuracy: 0.3219 - 4s/epoch - 14ms/step
# Epoch 13/30
# 312/312 - 5s - loss: 0.0357 - accuracy: 0.3266 - val_loss: -1.5420e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 14/30
# 312/312 - 5s - loss: 0.0351 - accuracy: 0.3266 - val_loss: -1.5407e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 15/30
# 312/312 - 5s - loss: 0.0351 - accuracy: 0.3266 - val_loss: -1.5096e-01 - val_accuracy: 0.3219 - 5s/epoch - 15ms/step
# Epoch 16/30
# 312/312 - 4s - loss: 0.0363 - accuracy: 0.3266 - val_loss: -1.4581e-01 - val_accuracy: 0.3219 - 4s/epoch - 12ms/step
# Epoch 17/30
# 312/312 - 3s - loss: 0.0371 - accuracy: 0.3266 - val_loss: -1.5291e-01 - val_accuracy: 0.3219 - 3s/epoch - 11ms/step
# Epoch 18/30
# 312/312 - 4s - loss: 0.0352 - accuracy: 0.3266 - val_loss: -1.5189e-01 - val_accuracy: 0.3219 - 4s/epoch - 13ms/step
# Epoch 19/30
# 312/312 - 5s - loss: 0.0337 - accuracy: 0.3266 - val_loss: -1.6015e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 20/30
# 312/312 - 4s - loss: 0.0352 - accuracy: 0.3266 - val_loss: -1.5597e-01 - val_accuracy: 0.3219 - 4s/epoch - 14ms/step
# Epoch 21/30
# 312/312 - 4s - loss: 0.0351 - accuracy: 0.3266 - val_loss: -1.5687e-01 - val_accuracy: 0.3219 - 4s/epoch - 12ms/step
# Epoch 22/30
# 312/312 - 4s - loss: 0.0364 - accuracy: 0.3266 - val_loss: -1.5382e-01 - val_accuracy: 0.3219 - 4s/epoch - 12ms/step
# Epoch 23/30
# 312/312 - 4s - loss: 0.0359 - accuracy: 0.3266 - val_loss: -1.5086e-01 - val_accuracy: 0.3219 - 4s/epoch - 12ms/step
# Epoch 24/30
# 312/312 - 4s - loss: 0.0372 - accuracy: 0.3266 - val_loss: -1.4977e-01 - val_accuracy: 0.3219 - 4s/epoch - 14ms/step
# Epoch 25/30
# 312/312 - 5s - loss: 0.0351 - accuracy: 0.3266 - val_loss: -1.4989e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 26/30
# 312/312 - 4s - loss: 0.0351 - accuracy: 0.3266 - val_loss: -1.5508e-01 - val_accuracy: 0.3219 - 4s/epoch - 13ms/step
# Epoch 27/30
# 312/312 - 4s - loss: 0.0346 - accuracy: 0.3266 - val_loss: -1.4849e-01 - val_accuracy: 0.3219 - 4s/epoch - 14ms/step
# Epoch 28/30
# 312/312 - 5s - loss: 0.0355 - accuracy: 0.3266 - val_loss: -1.4573e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 29/30
# 312/312 - 5s - loss: 0.0352 - accuracy: 0.3266 - val_loss: -1.4422e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 30/30
# 312/312 - 5s - loss: 0.0348 - accuracy: 0.3266 - val_loss: -1.4350e-01 - val_accuracy: 0.3219 - 5s/epoch - 15ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 72, 16)            249952
#
#  lstm (LSTM)                 (None, 32)                6272
#
#  dense_2 (Dense)             (None, 10)                330
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 256,565
# Trainable params: 256,565
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 312/312 - 11s - loss: 0.0828 - accuracy: 0.3266 - val_loss: -1.3288e-01 - val_accuracy: 0.3219 - 11s/epoch - 34ms/step
# Epoch 2/30
# 312/312 - 5s - loss: 0.0376 - accuracy: 0.3266 - val_loss: -1.5019e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 3/30
# 312/312 - 5s - loss: 0.0419 - accuracy: 0.3266 - val_loss: -1.5439e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 4/30
# 312/312 - 5s - loss: 0.0367 - accuracy: 0.3266 - val_loss: -1.4432e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 5/30
# 312/312 - 5s - loss: 0.0370 - accuracy: 0.3266 - val_loss: -1.5988e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 6/30
# 312/312 - 5s - loss: 0.0367 - accuracy: 0.3266 - val_loss: -1.4293e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 7/30
# 312/312 - 5s - loss: 0.0346 - accuracy: 0.3266 - val_loss: -1.6906e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 8/30
# 312/312 - 5s - loss: 0.0372 - accuracy: 0.3266 - val_loss: -1.5810e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 9/30
# 312/312 - 5s - loss: 0.0370 - accuracy: 0.3266 - val_loss: -1.6764e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 10/30
# 312/312 - 6s - loss: 0.0367 - accuracy: 0.3266 - val_loss: -1.6281e-01 - val_accuracy: 0.3219 - 6s/epoch - 18ms/step
# Epoch 11/30
# 312/312 - 5s - loss: 0.0385 - accuracy: 0.3266 - val_loss: -1.7585e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 12/30
# 312/312 - 5s - loss: 0.0402 - accuracy: 0.3266 - val_loss: -1.5417e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 13/30
# 312/312 - 5s - loss: 0.0363 - accuracy: 0.3266 - val_loss: -1.4950e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 14/30
# 312/312 - 5s - loss: 0.0384 - accuracy: 0.3266 - val_loss: -1.6090e-01 - val_accuracy: 0.3219 - 5s/epoch - 17ms/step
# Epoch 15/30
# 312/312 - 5s - loss: 0.0395 - accuracy: 0.3266 - val_loss: -1.4594e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 16/30
# 312/312 - 6s - loss: 0.0366 - accuracy: 0.3266 - val_loss: -1.4468e-01 - val_accuracy: 0.3219 - 6s/epoch - 18ms/step
# Epoch 17/30
# 312/312 - 6s - loss: 0.0359 - accuracy: 0.3266 - val_loss: -1.3563e-01 - val_accuracy: 0.3219 - 6s/epoch - 18ms/step
# Epoch 18/30
# 312/312 - 6s - loss: 0.0359 - accuracy: 0.3266 - val_loss: -1.4588e-01 - val_accuracy: 0.3219 - 6s/epoch - 18ms/step
# Epoch 19/30
# 312/312 - 6s - loss: 0.0374 - accuracy: 0.3266 - val_loss: -1.4436e-01 - val_accuracy: 0.3219 - 6s/epoch - 18ms/step
# Epoch 20/30
# 312/312 - 6s - loss: 0.0359 - accuracy: 0.3266 - val_loss: -1.4326e-01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 21/30
# 312/312 - 5s - loss: 0.0375 - accuracy: 0.3266 - val_loss: -1.4606e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 22/30
# 312/312 - 5s - loss: 0.0362 - accuracy: 0.3266 - val_loss: -1.4493e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 23/30
# 312/312 - 5s - loss: 0.0392 - accuracy: 0.3266 - val_loss: -1.3601e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 24/30
# 312/312 - 5s - loss: 0.0361 - accuracy: 0.3266 - val_loss: -1.2902e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 25/30
# 312/312 - 5s - loss: 0.0371 - accuracy: 0.3266 - val_loss: -1.5806e-01 - val_accuracy: 0.3219 - 5s/epoch - 15ms/step
# Epoch 26/30
# 312/312 - 5s - loss: 0.0378 - accuracy: 0.3266 - val_loss: -1.4037e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 27/30
# 312/312 - 5s - loss: 0.0376 - accuracy: 0.3266 - val_loss: -1.4598e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 28/30
# 312/312 - 5s - loss: 0.0369 - accuracy: 0.3266 - val_loss: -1.3395e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Epoch 29/30
# 312/312 - 5s - loss: 0.0360 - accuracy: 0.3266 - val_loss: -1.3909e-01 - val_accuracy: 0.3219 - 5s/epoch - 15ms/step
# Epoch 30/30
# 312/312 - 5s - loss: 0.0359 - accuracy: 0.3266 - val_loss: -1.3873e-01 - val_accuracy: 0.3219 - 5s/epoch - 16ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 72, 16)            249952
#
#  bidirectional (Bidirectiona  (None, 64)               12544
#  l)
#
#  dense_4 (Dense)             (None, 10)                650
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 263,157
# Trainable params: 263,157
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 312/312 - 14s - loss: 0.0705 - accuracy: 0.3268 - val_loss: -1.7650e-01 - val_accuracy: 0.3219 - 14s/epoch - 45ms/step
# Epoch 2/30
# 312/312 - 6s - loss: 0.0414 - accuracy: 0.3266 - val_loss: -1.6411e-01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 3/30
# 312/312 - 6s - loss: -2.4537e-01 - accuracy: 0.3266 - val_loss: -1.6342e+00 - val_accuracy: 0.3219 - 6s/epoch - 18ms/step
# Epoch 4/30
# 312/312 - 6s - loss: -9.9450e+00 - accuracy: 0.3287 - val_loss: -1.5490e+01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 5/30
# 312/312 - 6s - loss: -4.9842e+01 - accuracy: 0.3387 - val_loss: -4.2771e+01 - val_accuracy: 0.3293 - 6s/epoch - 20ms/step
# Epoch 6/30
# 312/312 - 6s - loss: -1.0858e+02 - accuracy: 0.3485 - val_loss: -2.4975e+01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 7/30
# 312/312 - 6s - loss: 4.3398 - accuracy: 0.3266 - val_loss: -2.4563e+01 - val_accuracy: 0.3219 - 6s/epoch - 19ms/step
# Epoch 8/30
# 312/312 - 7s - loss: 4.1949 - accuracy: 0.3266 - val_loss: -2.3861e+01 - val_accuracy: 0.3219 - 7s/epoch - 21ms/step
# Epoch 9/30
# 312/312 - 6s - loss: 3.9842 - accuracy: 0.3266 - val_loss: -2.3197e+01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 10/30
# 312/312 - 7s - loss: 3.5514 - accuracy: 0.3266 - val_loss: -2.2627e+01 - val_accuracy: 0.3219 - 7s/epoch - 21ms/step
# Epoch 11/30
# 312/312 - 6s - loss: 3.0044 - accuracy: 0.3266 - val_loss: -2.1691e+01 - val_accuracy: 0.3219 - 6s/epoch - 18ms/step
# Epoch 12/30
# 312/312 - 6s - loss: 1.6312 - accuracy: 0.3266 - val_loss: -2.1733e+01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 13/30
# 312/312 - 6s - loss: -1.5515e+00 - accuracy: 0.3266 - val_loss: -2.0585e+01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 14/30
# 312/312 - 6s - loss: -1.1078e+01 - accuracy: 0.3266 - val_loss: -2.6025e+01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 15/30
# 312/312 - 6s - loss: -3.1465e+01 - accuracy: 0.3266 - val_loss: -3.5099e+01 - val_accuracy: 0.3219 - 6s/epoch - 18ms/step
# Epoch 16/30
# 312/312 - 6s - loss: -6.6489e+01 - accuracy: 0.3266 - val_loss: -4.7973e+01 - val_accuracy: 0.3219 - 6s/epoch - 21ms/step
# Epoch 17/30
# 312/312 - 6s - loss: -1.3258e+02 - accuracy: 0.3266 - val_loss: -8.1917e+01 - val_accuracy: 0.3219 - 6s/epoch - 20ms/step
# Epoch 18/30
# 312/312 - 6s - loss: -2.4950e+02 - accuracy: 0.3439 - val_loss: -1.1101e+02 - val_accuracy: 0.3488 - 6s/epoch - 20ms/step
# Epoch 19/30
# 312/312 - 6s - loss: -3.5032e+02 - accuracy: 0.4016 - val_loss: -2.0583e+02 - val_accuracy: 0.3350 - 6s/epoch - 19ms/step
# Epoch 20/30
# 312/312 - 7s - loss: -6.1377e+02 - accuracy: 0.3953 - val_loss: -2.9997e+02 - val_accuracy: 0.3419 - 7s/epoch - 23ms/step
# Epoch 21/30
# 312/312 - 6s - loss: -8.5224e+02 - accuracy: 0.3917 - val_loss: -3.7671e+02 - val_accuracy: 0.3443 - 6s/epoch - 20ms/step
# Epoch 22/30
# 312/312 - 6s - loss: -1.1058e+03 - accuracy: 0.4035 - val_loss: -4.4259e+02 - val_accuracy: 0.3537 - 6s/epoch - 18ms/step
# Epoch 23/30
# 312/312 - 6s - loss: -1.3763e+03 - accuracy: 0.4115 - val_loss: -5.5297e+02 - val_accuracy: 0.3419 - 6s/epoch - 19ms/step
# Epoch 24/30
# 312/312 - 8s - loss: -1.5929e+03 - accuracy: 0.4070 - val_loss: -6.6939e+02 - val_accuracy: 0.3297 - 8s/epoch - 26ms/step
# Epoch 25/30
# 312/312 - 7s - loss: -1.9133e+03 - accuracy: 0.3940 - val_loss: -8.0780e+02 - val_accuracy: 0.3423 - 7s/epoch - 22ms/step
# Epoch 26/30
# 312/312 - 7s - loss: -2.2710e+03 - accuracy: 0.4057 - val_loss: -9.6385e+02 - val_accuracy: 0.3480 - 7s/epoch - 22ms/step
# Epoch 27/30
# 312/312 - 7s - loss: -2.5800e+03 - accuracy: 0.4184 - val_loss: -1.1167e+03 - val_accuracy: 0.3419 - 7s/epoch - 23ms/step
# Epoch 28/30
# 312/312 - 7s - loss: -2.6009e+03 - accuracy: 0.4120 - val_loss: -3.8568e+02 - val_accuracy: 0.3236 - 7s/epoch - 22ms/step
# Epoch 29/30
# 312/312 - 8s - loss: -3.0954e+03 - accuracy: 0.4243 - val_loss: -1.2258e+03 - val_accuracy: 0.3492 - 8s/epoch - 27ms/step
# Epoch 30/30
# 312/312 - 6s - loss: -3.5976e+03 - accuracy: 0.4229 - val_loss: -1.4946e+03 - val_accuracy: 0.3390 - 6s/epoch - 20ms/step
